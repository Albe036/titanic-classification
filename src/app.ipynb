# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_data = pd.read_csv('./data/train.csv', index_col='PassengerId')
print(f'rows and columns: {train_data.shape}')
train_data.head()
# Out:
# rows and columns: (891, 11)
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
plt.figure(figsize=(14,7))
plt.title('Prueba de grafico')
sns.scatterplot(x=train_data['Age'], y=train_data['Fare'], hue=train_data['Sex'])
# Out:
# <Axes: title={'center': 'Prueba de grafico'}, xlabel='Age', ylabel='Fare'>
